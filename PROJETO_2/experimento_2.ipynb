# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
print('Versão da OpenCV: ', cv2.__version__, end='\n\n')
# Out:
# Versão da OpenCV:  3.4.3

# %%
img = cv2.imread('/content/ed7a20a362adb57310f4bec8fcd28720.jpg', cv2.IMREAD_GRAYSCALE)
plt.imshow(img)

# %%
img.shape
# Out:
# (512, 512)

# %%
def simple_subsampling(img, n):
  lista_imagens = []
  for i in range(n+1):
    img = img[1::2, 1::2]
    lista_imagens.append(img)
        
  return lista_imagens

# %%
lista_imagens = simple_subsampling(img, 4)

# %%
lista_imagens[3].shape
# Out:
# (32, 32)

# %%
plt.figure(dpi=100)
plt.subplots(figsize=(20, 10))
plt.imshow(img)
plt.subplots(figsize=(10, 5))
plt.imshow(lista_imagens[0])
plt.subplots(figsize=(5, 2.5))
plt.imshow(lista_imagens[1])
plt.subplots(figsize=(2.5, 1.75))
plt.imshow(lista_imagens[2])
plt.subplots(figsize=(1.5, 0.75))
plt.imshow(lista_imagens[3])
plt.show()

# %% [markdown]
# https://gist.github.com/KeremTurgutlu/68feb119c9dd148285be2e247267a203

# %%
def nn_interpolate(A, new_size):
    """Vectorized Nearest Neighbor Interpolation"""

    old_size = A.shape
    row_ratio, col_ratio = np.array(new_size)/np.array(old_size)

    # row wise interpolation 
    row_idx = (np.ceil(range(1, 1 + int(old_size[0]*row_ratio))/row_ratio) - 1).astype(int)

    # column wise interpolation
    col_idx = (np.ceil(range(1, 1 + int(old_size[1]*col_ratio))/col_ratio) - 1).astype(int)

    final_matrix = A[:, row_idx][col_idx, :]

    return final_matrix

# %%
teste = nn_interpolate(lista_imagens[0], 512)

# %%
plt.figure()
plt.imshow(teste)
plt.show()
plt.imsave('fig1tets.png', teste)
plt.imshow(lista_imagens[0])
plt.show()
plt.savefig('fig2teste.png', lista_imagens[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-d54f3d67fb25> in <module>()
#       5 plt.imshow(lista_imagens[0])
#       6 plt.show()
# ----> 7 plt.savefig('fig2teste.png', lista_imagens[0])
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     687 def savefig(*args, **kwargs):
#     688     fig = gcf()
# --> 689     res = fig.savefig(*args, **kwargs)
#     690     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     691     return res
#
# TypeError: savefig() takes 2 positional arguments but 3 were given

# %%
teste1 = lista_imagens[0]
plt.figure()
plt.imshow(teste1)
plt.show()
plt.imsave('fig2tets.png', teste1)

# %%
img_2.shape
# Out:
# (256, 256)

# %%
newimg = block_mean(img, 2)

plt.imshow(newimg)
# Out:
# /usr/local/lib/python3.6/dist-packages/scipy/ndimage/measurements.py:670: RuntimeWarning: invalid value encountered in true_divide
#   return sum / numpy.asanyarray(count).astype(numpy.float)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-507e6343a0d2> in <module>()
# ----> 1 newimg = block_mean(img, 2)
#       2
#       3 plt.imshow(newimg)
#
# <ipython-input-49-3662fb1ab7ad> in block_mean(ar, fact)
#       8     regions = sy/fact * (X/fact) + Y/fact
#       9     res = ndimage.mean(ar, labels=regions, index=np.arange(regions.max() + 1))
# ---> 10     res.shape = int((sx/fact), (sy/fact))
#      11     return res
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
img_gray.shape
# Out:
# (512, 512)

# %%
plt.imshow(img_gray)

# %%
from skimage import color
from skimage import io

img = color.rgb2gray(io.imread('/content/ed7a20a362adb57310f4bec8fcd28720.jpg'))
plt.imshow(img)

# %%
https://gist.github.com/KeremTurgutlu/68feb119c9dd148285be2e247267a203
# Out:
#   File "<ipython-input-27-dfd8654f712d>", line 1
#     https://gist.github.com/KeremTurgutlu/68feb119c9dd148285be2e247267a203
#            ^
# SyntaxError: invalid syntax
